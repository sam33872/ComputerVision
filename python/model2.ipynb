# %%
## Import training_images.npz, testing_images.npz and examples.npz into the file
# !wget "http://users.sussex.ac.uk/~is321/training_images.npz" -O training_images.npz
# !wget "http://users.sussex.ac.uk/~is321/test_images.npz" -O test_images.npz
# !wget "http://users.sussex.ac.uk/~is321/examples.npz" -O examples.npz
# Out:
# --2020-05-28 14:53:32--  http://users.sussex.ac.uk/~is321/training_images.npz
# Resolving users.sussex.ac.uk (users.sussex.ac.uk)... 139.184.14.119
# Connecting to users.sussex.ac.uk (users.sussex.ac.uk)|139.184.14.119|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375302693 (358M)
# Saving to: ‘training_images.npz’
#
# training_images.npz 100%[===================>] 357.92M  76.1MB/s    in 5.0s
#
# 2020-05-28 14:53:37 (72.0 MB/s) - ‘training_images.npz’ saved [375302693/375302693]
#
# --2020-05-28 14:53:39--  http://users.sussex.ac.uk/~is321/test_images.npz
# Resolving users.sussex.ac.uk (users.sussex.ac.uk)... 139.184.14.119
# Connecting to users.sussex.ac.uk (users.sussex.ac.uk)|139.184.14.119|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74915629 (71M)
# Saving to: ‘test_images.npz’
#
# test_images.npz     100%[===================>]  71.44M  58.6MB/s    in 1.2s
#
# 2020-05-28 14:53:40 (58.6 MB/s) - ‘test_images.npz’ saved [74915629/74915629]
#
# --2020-05-28 14:53:41--  http://users.sussex.ac.uk/~is321/examples.npz
# Resolving users.sussex.ac.uk (users.sussex.ac.uk)... 139.184.14.119
# Connecting to users.sussex.ac.uk (users.sussex.ac.uk)|139.184.14.119|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 777627 (759K)
# Saving to: ‘examples.npz’
#
# examples.npz        100%[===================>] 759.40K  4.55MB/s    in 0.2s
#
# 2020-05-28 14:53:42 (4.55 MB/s) - ‘examples.npz’ saved [777627/777627]

# %%
import numpy as np
from skimage.color import rgb2gray

## Pre-processing on training data for Model 2

# Load data from training_images.npz
data = np.load('training_images.npz',allow_pickle=True)

# Stores the images from data in variable to represent training images
trainImages = data['images']

# Use rgb2gray function from skimage.color library to change image to grayscale
trainImages = rgb2gray(trainImages)

# Stores the points from data into variable for training points
pts = data['points']

for i in range(2811):
    for j in range(68):
        for k in range(2):
            # Check for any coordinates out of range
            # Change any coordinates above limit to 250
            if(pts[i][j][k] > 250):
                pts[i][j][k] = 250
            # Change any coordinates below limit to 0
            if(pts[i][j][k] < 0):
                pts[i][j][k] = 0
            # Change all coordinate values to be between -1 and 1
            pts[i][j][k] = pts[i][j][k] - 125
            pts[i][j][k] = pts[i][j][k] / 125

# Set both images and points to type float32
trainImages = trainImages.astype(np.float32)        
pts = pts.astype(np.float32)

# Reshape both images and pts to suitable sizes
trainImages = trainImages.reshape(2811, 250, 250 ,1)
pts = pts.reshape(2811, 136)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,Flatten, Dropout
from keras.layers import Dense, Activation
from keras.optimizers import SGD
from ipykernel import kernelapp as app

## Model 2

# Define new model using Sequential from Keras models
model2 = Sequential([
        # Added input layer, this layer is a 2D convolution layer from Keras Layers 
        # Set the dimensionality of the output space to 64
        # Set the size of the 2D convolution window to 3x3            
        Conv2D(64,(3, 3), input_shape = (250,250,1)),
        # Added an activation layer from Keras Layers
        # Applies an Activation function, doesn't affect output shape     
        Activation('relu'),
        # Added layer to perfrom max pooling operation for 2D spatial data
        # Window size set to 2x2
        MaxPooling2D(pool_size = (2,2)),
        # Added 2D convolution layer
        # Set the dimensionality of the output space to 128
        # Set the size of the 2D convolution window to 2x2  
        Conv2D(128,(2,2)),
        # Added another Activation layer
        Activation('relu'),
        # Added layer to perfrom max pooling operation for 2D spatial data
        # Window size set to 2x2
        MaxPooling2D(pool_size = (2,2)),
        # Added 2D convolution layer
        # Set the dimensionality of the output space to 256
        # Set the size of the 2D convolution window to 2x2  
        Conv2D(256,(2,2)),
        # Added another Activation layer
        Activation('relu'),
        # Added layer to perfrom max pooling operation for 2D spatial data
        # Window size set to 2x2
        MaxPooling2D(pool_size=(2,2)),
        # Added Flatten layer
        # Changes output size from (a,b,c) to (d) where d = a x b x c
        Flatten(),
        # Added Dense layer with output shape 500
        Dense(500),
        # Added another Activation layer
        Activation('relu'),
        # Added Dense layer with output shape 500
        Dense(500),
        # Added another Activation layer
        Activation('relu'),
        # Added another Dense Layer as the output layer, this time with output shape 136
        # This is the format needed as it represents the number of coordinates of points per image (68*2)
        Dense(136)
    ])

# Define new Stochastic Gradient Descent which will be used for the required optimizer in compiling the model
sgd = SGD(lr=0.01,momentum = 0.9,nesterov=True)
# Compiles the model using a mean squared error for loss and optimizer defined above
model2.compile(loss="mean_squared_error",optimizer=sgd)
# Out:
# Using TensorFlow backend.

# %%
## Train the model on the training images and points
model2.fit(trainImages,pts,nb_epoch=250,validation_split=0.2,verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 2248 samples, validate on 563 samples
# Epoch 1/250
# 2248/2248 [==============================] - 12s 6ms/step - loss: 0.0392 - val_loss: 0.0092
# Epoch 2/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 3/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 4/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 5/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 6/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 7/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 8/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 9/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 10/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 11/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 12/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 13/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 14/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 15/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 16/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 17/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 18/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 19/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 20/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 21/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 22/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 23/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 24/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 25/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 26/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 27/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 28/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 29/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 30/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 31/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 32/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 33/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 34/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 35/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 36/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 37/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 38/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 39/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 40/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 41/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 42/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 43/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 44/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 45/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 46/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 47/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 48/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 49/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 50/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 51/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 52/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 53/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 54/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 55/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 56/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 57/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 58/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 59/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 60/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 61/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 62/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 63/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 64/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 65/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 66/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 67/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 68/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 69/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 70/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 71/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 72/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 73/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 74/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 75/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 76/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 77/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 78/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 79/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 80/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 81/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 82/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 83/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 84/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 85/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 86/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 87/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 88/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 89/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 90/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 91/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 92/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 93/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 94/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 95/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 96/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 97/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 98/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 99/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 100/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 101/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 102/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 103/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 104/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 105/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 106/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 107/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 108/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 109/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 110/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 111/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 112/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 113/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 114/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 115/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 116/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 117/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 118/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 119/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 120/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 121/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 122/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 123/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 124/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 125/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 126/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 127/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 128/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 129/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 130/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 131/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 132/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 133/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 134/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 135/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 136/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 137/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 138/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 139/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 140/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 141/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 142/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 143/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 144/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 145/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 146/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 147/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 148/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 149/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 150/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 151/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 152/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 153/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 154/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 155/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 156/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 157/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 158/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 159/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 160/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 161/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 162/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 163/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 164/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 165/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 166/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 167/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 168/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 169/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 170/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 171/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 172/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 173/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 174/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 175/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 176/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 177/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 178/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 179/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 180/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 181/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 182/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 183/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 184/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 185/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 186/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 187/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 188/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 189/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 190/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 191/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 192/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 193/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 194/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 195/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 196/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 197/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 198/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 199/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 200/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 201/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 202/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 203/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 204/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 205/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 206/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 207/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 208/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 209/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 210/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 211/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 212/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 213/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 214/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 215/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 216/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 217/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 218/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 219/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 220/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 221/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 222/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 223/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 224/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 225/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 226/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 227/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 228/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 229/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 230/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 231/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 232/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 233/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 234/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 235/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 236/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 237/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 238/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 239/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 240/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 241/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 242/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 243/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 244/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 245/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 246/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 247/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 248/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 249/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 250/250
# 2248/2248 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019

# %%
# Outputs a summary of the model to show each step and the output shape
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 248, 248, 64)      640
# _________________________________________________________________
# activation_1 (Activation)    (None, 248, 248, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 124, 124, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 123, 123, 128)     32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 123, 123, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 61, 61, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 256)       131328
# _________________________________________________________________
# activation_3 (Activation)    (None, 60, 60, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 230400)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               115200500
# _________________________________________________________________
# activation_4 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# activation_5 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 136)               68136
# =================================================================
# Total params: 115,684,000
# Trainable params: 115,684,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Pre-processing of testing data

# Import testing data from file
test = np.load('test_images.npz',allow_pickle=True)

# Store testing images in a variable
testImages = test['images']

# Set images to grayscale
testImages = rgb2gray(testImages)

# Set images to datatype float32
testImages = testImages.astype(np.float32)

# Reshape images to suitable size
testImages = testImages.reshape(554,250,250,1)

# %%
## Use model to predict points on testing images
predictedPts = model2.predict(testImages)

# %%
def save_as_csv(points, location = 'drive/My Drive/model2'):
  """
  Save the points out as a .csv file
  :param points: numpy array of shape (no_image, no_points, 2) to be saved
  :param location: Directory to save results.csv in. Default to current working directory
  """
  np.savetxt(location + '/results.csv', np.reshape(points, (points.shape[0], -1)), delimiter=',')

predictedPts.reshape(-1,68,2)
save_as_csv(predictedPts)

# %%
## Function to plot a singular image with its predicted points
def plotSample(image,points,axes):
  
    # Reshapes image to correct size and sets image type to grayscale
    axes.imshow(image.reshape(250,250),cmap="gray")

    # Sets the predicted points on screen
    # Changes values back from -1 to 1 to be between 0 and 250
    axes.scatter(125*points[0::2]+ 125,125*points[1::2]+ 125)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

## Function to plot a sequence of three sequential images
# Starting point is defined in parameter
def plotImages(start):

  # Sets up the features of each figure
  fig = plt.figure(figsize=(12, 12))
  fig.subplots_adjust(hspace=0.10,wspace=0.0001,
                    left=0,right=1,bottom=0, top=1)

  # j represents the position in the plotted structure for a given image
  j = 1

  # Loops from the passed position and the two sequential positions in testing images
  for i in range(start,start+3):

    # Sets up a new subplot for next image, in position j
    ax = fig.add_subplot(3 , 3, j,xticks=[],yticks=[])  

    # Calls plotSample to plot image in position i into the subplot      
    plotSample(testImages[i],predictedPts[i],ax)

    # Increment j
    j += 1

  # Display figures
  plt.show()

# %%
## Call to plotImages to display 3 images with prediced points
plotImages(0)

# %%
## Function to calculate euclidean distance between predicted and real points
def euclid_dist(pred_pts, gt_pts):
  """
  Calculate the euclidean distance between pairs of points
  :param pred_pts: The predicted points
  :param gt_pts: The ground truth points
  :return: An array of shape (no_points,) containing the distance of each predicted point from the ground truth
  """
  import numpy as np
  pred_pts = np.reshape(pred_pts, (-1, 2))
  gt_pts = np.reshape(gt_pts, (-1, 2))
  return np.sqrt(np.sum(np.square(pred_pts - gt_pts), axis=-1))

# %%
## Calculate euclidean distance between predictions and real points on training images

# Use model to predict points on training images
predictedPoints = model2.predict(trainImages)

# Copy real points into new variable
basePoints = pts.copy()

# Reshape points to be in suitable format for comparison (between 0 and 250)
predictedPoints = predictedPoints * 125
predictedPoints = predictedPoints + 125
basePoints = basePoints * 125
basePoints = basePoints + 125

# Calculate the mean of all distances
np.mean(euclid_dist(predictedPoints,basePoints))
# Out:
# 5.403675

# %%
## Pre-processing of example images
# Load data from file
example = np.load('examples.npz',allow_pickle=True)

# Extract images from data
exampleImages = example['images']

# Change images to grayscale
exampleImages = rgb2gray(exampleImages)

# Reshape image for use in model
exampleImages = exampleImages.reshape(-1,250,250,1)

# Use model to predict points on example images
predictedPts2 = model2.predict(exampleImages)

# %%
# Sets up the features of each figure
fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(hspace=0.10,wspace=0.0001,
                    left=0,right=1,bottom=0, top=1)

# j represents the position in the plotted structure for a given image
j = 1

# Loops from the passed position and the two sequential positions in testing images
for i in range(start,start+6):

    # Sets up a new subplot for next image, in position j
    ax = fig.add_subplot(3 , 3, j,xticks=[],yticks=[])  

    # Calls plotSample to plot image in position i into the subplot      
    plotSample(exampleImages[i],predictedPts2[i],ax)

    # Increment j
    j += 1

# Display figures
plt.show()

# %%
## Plot points on example images
plotImages2
